# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from tabula import read_pdf

# %%
import sys
import os
sys.path.append(os.path.abspath('Python_Code'))
from CleaningData import Berlin
from CleaningData import Pdf2Json
data_path = 'Data'
Berlin = Berlin('Berlin', 2017, 2023, data_path)

# %% [markdown]
# # Data

# %% [markdown]
# ## Berlin

# %%
berlin_pdf_files = '../VdZ_Geschäftsberichte/Berlin/'
pdf_list = os.listdir(berlin_pdf_files)
year_list = list(range(2017, 2023))
save_path = 'Data/Berlin'
for file, year in zip(pdf_list, year_list):
    if file.endswith('.pdf'):
        print(file)
        Berlin.pdf2json_above2down(berlin_pdf_files + file, year, save_path)
# Out:
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'
# Geschaeftsbericht_AG_2017.pdf
# Geschaeftsbericht_AG_2018.pdf
# Geschaeftsbericht_AG_2019.pdf
# Geschaeftsbericht_AG_2020.pdf
# Got stderr: Mär 02, 2025 3:24:00 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNUNG: No Unicode mapping for f_j (25) in font WUFXNZ+MyriadPro-Light
# Mär 02, 2025 3:24:00 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNUNG: No Unicode mapping for f_l (31) in font WUFXNZ+MyriadPro-LightIt
# Mär 02, 2025 3:24:01 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNUNG: No Unicode mapping for f_i (30) in font WUFXNZ+MyriadPro-LightIt
# Mär 02, 2025 3:24:03 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNUNG: No Unicode mapping for f_f (31) in font XCPDBX+MyriadPro-Regular
# Mär 02, 2025 3:24:10 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# ...

# %%
forgotten_file = berlin_pdf_files + '2023.pdf'
test = '../VdZ_Geschäftsberichte/Berlin/Geschaeftsbericht_AG_2023.pdf'
Berlin.pdf2json_above2down(test, 2023, save_path)

# %% [markdown]
# ## Köln
